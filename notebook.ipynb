# %%
import os
import numpy as np
from keras import Sequential
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
filename = './data/BRATS2015_Training/HGG/brats_tcia_pat198_0283/VSD.Brain.XX.O.MR_T1.35713/VSD.Brain.XX.O.MR_T1.35713.mha'

# %%
import SimpleITK as sitk
ct_scans = sitk.GetArrayFromImage(sitk.ReadImage(filename, sitk.sitkFloat32))
plt.figure(figsize=(20,16))
plt.gray()
plt.subplots_adjust(0,0,1,1,0.01,0.01)
print(ct_scans.shape[0])
for i in range(ct_scans.shape[0]):
    plt.subplot(23,8,i+1), plt.imshow(ct_scans[i]), plt.axis('off')
    # use plt.savefig(...) here if you want to save the images as .jpg, e.g.,
plt.show()
# Out:
# 155

# %%
plt.imshow(ct_scans[100]), plt.axis('off')
# Out:
# (<matplotlib.image.AxesImage at 0x15f0e2dd0>, (-0.5, 239.5, 239.5, -0.5))

# %%
plt.imshow(ct_scans[100]), plt.axis('on')
# Out:
# (<matplotlib.image.AxesImage at 0x1613502d0>, (-0.5, 239.5, 239.5, -0.5))
